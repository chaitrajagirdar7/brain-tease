# %%
import pandas as pd
import matplotlib.pyplot as mp
# %matplotlib inline

# %%
Targetfile=pd.read_excel("C://Users//Manju//Desktop//DataSets//Visualization11.xlsx","Visualization")
type(Targetfile['Date'][0])
Targetfile
# Out:
#         Date  Age   Name
# 0 2019-12-12   90   chai
# 1 2019-12-13   67    aks
# 2 2019-12-14   40    ven
# 3 2019-12-15   78    ben
# 4 2019-12-16   56   lila
# 5 2019-12-17   99   jila
# 6 2019-12-18  101  lijji

# %%
mp.plot(Targetfile['Age'],Targetfile['Date'] ,color='green', marker='o', linestyle='dashed',
...      linewidth=10, markersize=10)
mp.xlabel('Age')
mp.ylabel('Date')
mp.title('Date vs Age')
# Out:
# Text(0.5, 1.0, 'Date vs Age')

# %%
mp.plot(Targetfile['Age'],Targetfile['Date'] ,color='r', marker='>', linestyle=':',
...      linewidth=10, markersize=25,alpha=0.5)
mp.xlabel('Age')
mp.ylabel('Date')
mp.title('Date vs Age')
mp.grid()
