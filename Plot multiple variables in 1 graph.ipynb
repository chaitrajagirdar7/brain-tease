# %%
import pandas as pd
import matplotlib.pyplot as mp
# %matplotlib inline

Targetfile=pd.read_excel("C://Users//Manju//Desktop//DataSets//Visualization11.xlsx","MultipleParameters")
type(Targetfile['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
Targetfile
# Out:
#         Date  Age   Name  Weight  BloodPressure
# 0 2019-12-12   90   chai     120            187
# 1 2019-12-13   67    aks      45            178
# 2 2019-12-14   40    ven      66            187
# 3 2019-12-15   78    ben      99            250
# 4 2019-12-16   56   lila     122            187
# 5 2019-12-17   99   jila      34            230
# 6 2019-12-18  101  lijji      90            111

# %%
mp.plot(Targetfile['Age'],Targetfile['Date'] ,color='green', marker='o', linestyle='dashed',
...      linewidth=10, markersize=20,label='Age')
mp.plot(Targetfile['Weight'],Targetfile['Date'] ,color='red', marker='+', linestyle='dashed',
...      linewidth=10, markersize=20,label='Weight')
mp.plot(Targetfile['BloodPressure'],Targetfile['Date'] ,color='blue', marker='+', linestyle='dashed',
...      linewidth=10, markersize=20,label='Bp')

mp.xlabel('Age vs Weight vs bp')
mp.ylabel('Date')
mp.title('Date vs Age vs Weight vs bp')

mp.legend(loc="best",shadow=True,fontsize="small")
mp.grid()
